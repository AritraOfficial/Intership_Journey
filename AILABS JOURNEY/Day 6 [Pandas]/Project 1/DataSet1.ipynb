# %% [markdown]
# # DataSet Project

# %%
import pandas as pd
df = pd.read_csv('Exchange Rates from 1975-2022.csv')
df
# Out:
#                       Table 340-46001 : Exchange Rates Unnamed: 1  \
# 0                                                             NaN
# 1
# 2                                                  NaN        NaN
# 3                                                 Year      Month
# 4                                                 1975        NaN
# ..                                                 ...        ...
# 638                                                           NaN
# 639                                            Source:        NaN
# 640  Trade Analysis Section,Census and Statistics D...        NaN
# 641                                                           NaN
# 642                         Release Date: 1 June, 2023        NaN
#
#                                  Unnamed: 2  \
# 0                                       NaN
# 1                         Australian Dollar
# 2    HK dollar per unit of foreign currency
# 3                                       NaN
# ...
