# %%
import pandas as pd

# %% [markdown]
# Find the current directory

# %%
ls
# Out:
#  Volume in drive E is Aritra
#  Volume Serial Number is 864D-ACBB
#
#  Directory of E:\University Ofiicial\3RD YEAR\AILABS JOURNEY\Day 7
#
# 30-06-2023  11:32 AM    <DIR>          .
# 30-06-2023  11:00 AM    <DIR>          ..
# 30-06-2023  11:32 AM    <DIR>          .ipynb_checkpoints
# 30-06-2023  11:03 AM             1,173 addresses.csv
# 30-06-2023  11:30 AM            38,713 Day 7.ipynb
# 30-06-2023  11:32 AM                72 Untitled.ipynb
#                3 File(s)         39,958 bytes
#                3 Dir(s)  536,312,614,912 bytes free

# %%
pd.read_csv('addresses.csv') 
#read the file by direct
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
pd.read_csv(r'E:\University Ofiicial\3RD YEAR\AILABS JOURNEY\Day 7\addresses.csv')
#Read the files usin the current directory path
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
pd.read_csv(r'E:\University Ofiicial\3RD YEAR\AILABS JOURNEY\Day 7\addresses.csv', header= None)
#Header is none means the columns name is becomes vlaues (changes the datatype from numerical to string)
# Out:
#      0            1                           2          3  \
# 0   id  location_id                   address_1  address_2
# 1    1            1       2600 Middlefield Road        NaN
# 2    2            2            24 Second Avenue        NaN
# 3    3            3            24 Second Avenue        NaN
# 4    4            4            24 Second Avenue        NaN
# 5    5            5            24 Second Avenue        NaN
# 6    6            6           800 Middle Avenue        NaN
# 7    7            7              500 Arbor Road        NaN
# 8    8            8           800 Middle Avenue        NaN
# 9    9            9       2510 Middlefield Road        NaN
# 10  10           10       1044 Middlefield Road        NaN
# 11  11           11         2140 Euclid Avenue.        NaN
# 12  12           12       1044 Middlefield Road  2nd Floor
# 13  13           13         399 Marine Parkway.        NaN
# 14  14           14          660 Veterans Blvd.        NaN
# ...

# %%
pd.read_csv(r'E:\University Ofiicial\3RD YEAR\AILABS JOURNEY\Day 7\addresses.csv', names =  ['a','b','c','d','e','f','g','h'])
# Out:
#      a            b                           c          d  \
# 0   id  location_id                   address_1  address_2
# 1    1            1       2600 Middlefield Road        NaN
# 2    2            2            24 Second Avenue        NaN
# 3    3            3            24 Second Avenue        NaN
# 4    4            4            24 Second Avenue        NaN
# 5    5            5            24 Second Avenue        NaN
# 6    6            6           800 Middle Avenue        NaN
# 7    7            7              500 Arbor Road        NaN
# 8    8            8           800 Middle Avenue        NaN
# 9    9            9       2510 Middlefield Road        NaN
# 10  10           10       1044 Middlefield Road        NaN
# 11  11           11         2140 Euclid Avenue.        NaN
# 12  12           12       1044 Middlefield Road  2nd Floor
# 13  13           13         399 Marine Parkway.        NaN
# 14  14           14          660 Veterans Blvd.        NaN
# ...

# %%
pd.read_csv('addresses.csv',names =['d','e','f','g','h']).head(2)
# Out:
#                                               d             e               f  \
# id location_id address_1              address_2          city  state_province
# 1  1           2600 Middlefield Road        NaN  Redwood City              CA
#
#                                                 g        h
# id location_id address_1              postal_code  country
# 1  1           2600 Middlefield Road        94063       US

# %%
pd.read_csv('addresses.csv',names =['d','e','f','g','h']).index
# Out:
# MultiIndex([('id', 'location_id',                  'address_1'),
#             ( '1',           '1',      '2600 Middlefield Road'),
#             ( '2',           '2',           '24 Second Avenue'),
#             ( '3',           '3',           '24 Second Avenue'),
#             ( '4',           '4',           '24 Second Avenue'),
#             ( '5',           '5',           '24 Second Avenue'),
#             ( '6',           '6',          '800 Middle Avenue'),
#             ( '7',           '7',             '500 Arbor Road'),
#             ( '8',           '8',          '800 Middle Avenue'),
#             ( '9',           '9',      '2510 Middlefield Road'),
#             ('10',          '10',      '1044 Middlefield Road'),
#             ('11',          '11',        '2140 Euclid Avenue.'),
#             ('12',          '12',      '1044 Middlefield Road'),
#             ('13',          '13',        '399 Marine Parkway.'),
# ...

# %%
df = pd.read_csv('addresses.csv',names =['a','b','c','d','e','f','g','h'])
df[0:0]['a']
# Out:
# Series([], Name: a, dtype: object)

# %%
pd.read_csv('addresses.csv',names =['d','e','f','g','h']).loc

# %%
pd.read_csv('addresses.csv',names =['d','e','f','g','h']).iloc

# %%
df.dtypes
# Out:
# a    object
# b    object
# c    object
# d    object
# e    object
# f    object
# g    object
# h    object
# dtype: object

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'], dtype='object')

# %%
df[['e','f']][:4]
# Out:
#               e               f
# 0          city  state_province
# 1  Redwood City              CA
# 2     San Mateo              CA
# 3     San Mateo              CA

# %%
df1 = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
df1
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df1)
# Out:
# list

# %%
df1 = pd.DataFrame(df1[0])

# %%
len(df1)
# Out:
# 675

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df2 = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')
df2
# Out:
# [                Player       Span  Mat Inns  NO  Runs   HS    Ave      SR 100  \
#  0           AB Agarkar  2006-2007    4    2   0    15   14   7.50  136.36   -
#  1             KK Ahmed  2018-2019   14    1   1     1   1*      -  100.00   -
#  2            S Aravind  2015-2015    1    -   0     -    -      -    0.00   -
#  3       Arshdeep Singh  2022-2023   26    5   5     6   2*      -   60.00   -
#  4             R Ashwin  2010-2022   65   19  12   184  31*  26.28  115.00   -
#  ..                 ...        ...  ...  ...  ..   ...  ...    ...     ...  ..
#  97       R Vinay Kumar  2010-2013    9    1   1     2   2*      -   50.00   -
#  98   Washington Sundar  2017-2023   35   14   4   107   50  10.70  152.85   -
#  99            SA Yadav  2021-2023   48   46  10  1675  117  46.52  175.76   3
#  100           UT Yadav  2012-2022    9    2   1    22  20*  22.00  104.76   -
#  101       Yuvraj Singh  2007-2017   58   51   9  1177  77*  28.02  136.38   -
#
#       50  0
# ...

# %%
type(df2)
# Out:
# list

# %%
df2 = pd.DataFrame(df2[0])  #convert into dataFrame

# %%
len(df2)
# Out:
# 102

# %%
df2.shape
# Out:
# (102, 12)

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df5 = pd.read_excel('excel-spreadsheet-examples-for-students.xls')
df5
# Out:
#     First Name Last Name                Company Name                 Address  \
# 0     Rebbecca     Didio      Brandt, Jonathan F Esq           171 E 24th St
# 1       Stevie     Hallo  Landrum Temporary Services          22222 Acoma St
# 2       Mariko    Stayer         Inabinet, Macre Esq   534 Schoenborn St #51
# 3      Gerardo    Woodka    Morris Downing & Sherred       69206 Jackson Ave
# 4        Mayra      Bena          Buelt, David L Esq       808 Glen Cove Ave
# ..         ...       ...                         ...                     ...
# 495      Miles   Feldner   Antietam Cable Television  28465 Downey Ave #4238
# 496      Julio     Mikel           Lombardi Bros Inc     2803 N Catalina Ave
# 497       Aide     Ghera       Nathaniel Electronics       22 Livingston Ave
# 498     Noelia  Brackett     Rodriguez, Joseph A Esq      403 Conn Valley Rd
# 499     Lenora  Delacruz     Stilling, William J Esq          5400 Market St
#
# ...

# %%
df5 = pd.read_excel('excel-spreadsheet-examples-for-students.xls', sheet_name='short')
df5
# Out:
#     First Name Last Name                Company Name                 Address
# 0     Rebbecca     Didio      Brandt, Jonathan F Esq           171 E 24th St
# 1       Stevie     Hallo  Landrum Temporary Services          22222 Acoma St
# 2       Mariko    Stayer         Inabinet, Macre Esq   534 Schoenborn St #51
# 3      Gerardo    Woodka    Morris Downing & Sherred       69206 Jackson Ave
# 4        Mayra      Bena          Buelt, David L Esq       808 Glen Cove Ave
# ..         ...       ...                         ...                     ...
# 495      Miles   Feldner   Antietam Cable Television  28465 Downey Ave #4238
# 496      Julio     Mikel           Lombardi Bros Inc     2803 N Catalina Ave
# 497       Aide     Ghera       Nathaniel Electronics       22 Livingston Ave
# 498     Noelia  Brackett     Rodriguez, Joseph A Esq      403 Conn Valley Rd
# 499     Lenora  Delacruz     Stilling, William J Esq          5400 Market St
#
# [500 rows x 4 columns]

# %%
df8 = pd.ExcelFile('excel-spreadsheet-examples-for-students.xls')
df8
df8.sheet_names
# Out:
# ['big', 'short']

# %%
sheet_name_list = df8.sheet_names

# %%
df8.parse('short')
# Out:
#     First Name Last Name                Company Name                 Address
# 0     Rebbecca     Didio      Brandt, Jonathan F Esq           171 E 24th St
# 1       Stevie     Hallo  Landrum Temporary Services          22222 Acoma St
# 2       Mariko    Stayer         Inabinet, Macre Esq   534 Schoenborn St #51
# 3      Gerardo    Woodka    Morris Downing & Sherred       69206 Jackson Ave
# 4        Mayra      Bena          Buelt, David L Esq       808 Glen Cove Ave
# ..         ...       ...                         ...                     ...
# 495      Miles   Feldner   Antietam Cable Television  28465 Downey Ave #4238
# 496      Julio     Mikel           Lombardi Bros Inc     2803 N Catalina Ave
# 497       Aide     Ghera       Nathaniel Electronics       22 Livingston Ave
# 498     Noelia  Brackett     Rodriguez, Joseph A Esq      403 Conn Valley Rd
# 499     Lenora  Delacruz     Stilling, William J Esq          5400 Market St
#
# [500 rows x 4 columns]

# %%
for i in sheet_name_list:
    df6 =  pd.read_excel('excel-spreadsheet-examples-for-students.xls', sheet_name='short')
df6
# Out:
#     First Name Last Name                Company Name                 Address
# 0     Rebbecca     Didio      Brandt, Jonathan F Esq           171 E 24th St
# 1       Stevie     Hallo  Landrum Temporary Services          22222 Acoma St
# 2       Mariko    Stayer         Inabinet, Macre Esq   534 Schoenborn St #51
# 3      Gerardo    Woodka    Morris Downing & Sherred       69206 Jackson Ave
# 4        Mayra      Bena          Buelt, David L Esq       808 Glen Cove Ave
# ..         ...       ...                         ...                     ...
# 495      Miles   Feldner   Antietam Cable Television  28465 Downey Ave #4238
# 496      Julio     Mikel           Lombardi Bros Inc     2803 N Catalina Ave
# 497       Aide     Ghera       Nathaniel Electronics       22 Livingston Ave
# 498     Noelia  Brackett     Rodriguez, Joseph A Esq      403 Conn Valley Rd
# 499     Lenora  Delacruz     Stilling, William J Esq          5400 Market St
#
# [500 rows x 4 columns]
